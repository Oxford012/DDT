# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
data = pd.read_csv("/Users/florianlichius/Daten/bluebikes_2017_2018")
data.head()
data = pd.DataFrame(data)
data.head()
# Out:
#    number           start_time             end_time  start_station_id  \
# 0       0  2018-08-28 07:01:05  2018-08-28 07:06:57               137
# 1       1  2018-04-11 18:21:53  2018-04-11 18:35:06               122
# 2       2  2018-11-28 17:08:21  2018-11-28 17:22:44                22
# 3       3  2018-05-29 08:13:13  2018-05-29 08:23:12                88
# 4       4  2018-07-13 06:26:24  2018-07-13 06:34:04                47
#
#    start_station_lat  start_station_lon  end_station_id  end_station_lat  \
# 0          42.398365         -71.107818             220        42.396384
# 1          42.345733         -71.100694             179        42.355601
# 2          42.352175         -71.055547              98        42.371848
# 3          42.374035         -71.101427             107        42.362500
# 4          42.362811         -71.056067              64        42.351004
#
#    end_station_lon  bike_id
# 0       -71.120105     3296
# 1       -71.103945     1766
# ...

# %%
#data.drop("number", axis=1, inplace=True)
test = pd.DataFrame(data['bike_id'])
test
# Out:
#          bike_id
# 0           3296
# 1           1766
# 2           2585
# 3           2768
# 4           1002
# ...          ...
# 3081595     3559
# 3081596     1113
# 3081597      700
# 3081598     1325
# 3081599     3233
#
# [3081600 rows x 1 columns]

# %%
# Number of observations per bike
plt.hist(data['bike_id'],bins=100)
plt.xlabel('Bike ID')
plt.ylabel('Number of Observations')
plt.title('Number of Observations per Bike')
plt.show()

# %%
# Number of observations per start station
fig, ax = plt.subplots(figsize=(15, 7))
plt.hist(data['start_station_id'], bins=100)
plt.xlabel('Station ID')
plt.ylabel('Number of Observations')
plt.title('Number of Observations per Station')
plt.show()

# %%
# Number of observations per end station
fig, ax = plt.subplots(figsize=(15, 7))
plt.hist(data['end_station_id'], bins=100)
plt.xlabel('Station ID')
plt.ylabel('Number of Observations')
plt.title('Number of Observations per Station')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))
stations = [data['start_station_id'], data['end_station_id']]
ax.hist(stations, bins=100, label=['Start Station', 'End Station'] )
plt.xlabel('Station ID')
plt.ylabel('Number of Observations')
plt.title('Number of Observations per Station')
plt.legend(loc='upper right')
plt.show()
