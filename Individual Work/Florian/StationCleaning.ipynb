# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from data_cleaning import clean_data
import folium
from geopy.distance import geodesic

# %% [markdown]
# ## Usefull functions

# %% [markdown]
# ### Generate maps

# %%
def map_stations_all_cords(data):
    bluebikes_start_stations_map_points = folium.Map(location=(42.361145, -71.057083), tiles="OpenStreetMap", zoom_start=12)

    # draw positions for the stations
    # whether we choose the coordinates from start or end station does not matter since they are the same
    #i want a red icon
    for key, value in data.items():
            color = ['red', 'green', 'blue', 'orange', 'white']
            i = 0
            for point in value:
                folium.Marker(location=point, icon=folium.Icon(color=color[i]), popup=(str(key) + "\n" + str(point))).add_to(bluebikes_start_stations_map_points)
                i += 1
        
    return bluebikes_start_stations_map_points

# %%
def map_stations_with_multiple_coordinates(data):
    bluebikes_start_stations_map_points = folium.Map(location=(42.361145, -71.057083), tiles="OpenStreetMap", zoom_start=12)

    # draw positions for the stations
    # whether we choose the coordinates from start or end station does not matter since they are the same
    #i want a red icon
    for key, value in data.items():
        if(len(value) > 1):
            color = ['red', 'green', 'blue', 'orange', 'white']
            i = 0
            for point in value:
                folium.Marker(location=point, icon=folium.Icon(color=color[i]), popup=(str(key) + "\n" + str(point))).add_to(bluebikes_start_stations_map_points)
                i += 1
        
    return bluebikes_start_stations_map_points

# %%
#Idea based on following chatGPT-Prompt:
# i have an dic with a key with lon and lat data attached. I want to show only data on a folium map 
#where the points in the array have a certain distance. How do i do that?

def far_away_map(pointDict, distance):
    far_away_dict = {}
    bosten = (42.361145, -71.057083)
    for key, value in pointDict.items():
        if(len(value) > 1):
            reference = value[0]
            for point in value[1:]:
                if(geodesic(point, reference).miles >distance):
                    if not key in far_away_dict:
                        far_away_dict[key] = value
        if(len(value) >= 1):    
            if(geodesic(value[0], bosten).miles > 10):
                if not key in far_away_dict:
                    far_away_dict[key] = value

    far_away_map_all = folium.Map(location=(42.361145, -71.057083), tiles="OpenStreetMap", zoom_start=10)

    for key, value in far_away_dict.items():
        color = ['red', 'green', 'blue', 'orange', 'yellow']
        i = 0
        for point in value:
            folium.Marker(location=point, icon=folium.Icon(color=color[i]), popup=(str(key) + "\n" + str(point))).add_to(far_away_map_all)
            i += 1
    return far_away_map_all

# %% [markdown]
# ### Data functions

# %%
#takes about 10 minutes to run
def get_station_dict(data):
    all_station = {}
    end_dict ={}
    start_dict = {}
    for row in data.iterrows():
        if row[1].start_station_id in start_dict:
            if not (row[1].start_station_lat, row[1].start_station_lon) in start_dict[row[1].start_station_id]:
                start_dict[row[1].start_station_id].append((row[1].start_station_lat, row[1].start_station_lon))
        else:
            start_dict[row[1].start_station_id] = [(row[1].start_station_lat, row[1].start_station_lon)]
        if row[1].end_station_id in end_dict:
            if not (row[1].end_station_lat, row[1].end_station_lon) in end_dict[row[1].end_station_id]:
                end_dict[row[1].end_station_id].append((row[1].end_station_lat, row[1].end_station_lon))
        else:
            end_dict[row[1].end_station_id] = [(row[1].end_station_lat, row[1].end_station_lon)]

        if row[1].start_station_id in all_station:
            if not (row[1].start_station_lat, row[1].start_station_lon) in all_station[row[1].start_station_id]:
                all_station[row[1].start_station_id].append((row[1].start_station_lat, row[1].start_station_lon))
        else:
            all_station[row[1].start_station_id] = [(row[1].start_station_lat, row[1].start_station_lon)]
        if row[1].end_station_id in all_station:
            if not (row[1].end_station_lat, row[1].end_station_lon) in all_station[row[1].end_station_id]:
                all_station[row[1].end_station_id].append((row[1].end_station_lat, row[1].end_station_lon))
        else:
            all_station[row[1].end_station_id] = [(row[1].end_station_lat, row[1].end_station_lon)]    

    return start_dict, end_dict, all_station

# %% [markdown]
# ## Load data

# %%
bluebikes = clean_data(r"C:\Users\STH_0\Desktop\Data\bluebikes_2017_2018")
bluebikes.head(5)
# Out:
#            start_time            end_time  start_station_id  end_station_id  \
# 0 2017-01-01 00:06:58 2017-01-01 00:12:49                67             139
# 1 2017-01-01 00:13:16 2017-01-01 00:28:07                36              10
# 2 2017-01-01 00:16:17 2017-01-01 00:44:10                36               9
# 3 2017-01-01 00:21:22 2017-01-01 00:33:50                46              19
# 4 2017-01-01 00:30:06 2017-01-01 00:40:28                10               8
#
#    bike_id  weekday
# 0      644        6
# 1      230        6
# 2      980        6
# 3     1834        6
# 4      230        6

# %% [markdown]
# ## Get positions of every station id

# %%
# get all stations with their coordinates
start_dict, end_dict, all_station = get_station_dict(bluebikes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # get all stations with their coordinates
# ----> 2 start_dict, end_dict, all_station = get_station_dict(bluebikes)
#
# Cell In[5], line 11, in get_station_dict(data)
#       9         start_dict[row[1].start_station_id].append((row[1].start_station_lat, row[1].start_station_lon))
#      10 else:
# ---> 11     start_dict[row[1].start_station_id] = [(row[1].start_station_lat, row[1].start_station_lon)]
#      12 if row[1].end_station_id in end_dict:
#      13     if not (row[1].end_station_lat, row[1].end_station_lon) in end_dict[row[1].end_station_id]:
#
# File c:\Users\STH_0\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'start_station_lat'

# %%
start_dict.keys().__len__()
# Out:
# 318

# %%
end_dict.keys().__len__()
# Out:
# 319

# %%
i = 0
for key, value in start_dict.items():
    if len(value) > 1:
        #print(str(key) + ": "    + str(value))
        i += 1
i
# Out:
# 72

# %%
i = 0
for key, value in end_dict.items():
    if len(value) > 1:
        #print(str(key) + ": "    + str(value))
        i += 1
i
# Out:
# 68

# %%
#compare start and end station
i = 0
for key, value in start_dict.items():
    if key in end_dict:
        if value != end_dict[key]:
            print(str(key) + ": "    + str(value) + " != " + str(end_dict[key]))
            i += 1
i
# Out:
# 77: [(42.386844, -71.09812), (42.396386809455, -71.12226963043213)] != [(42.386844, -71.09812)]
# 217: [(42.38673178529929, -71.00621223455164), (42.386781, -71.006098)] != [(42.386781, -71.006098)]
# 135: [(42.344827, -71.028664), (42.353334, -71.09850591982195)] != [(42.344827, -71.028664)]
# 201: [(42.316873, -71.091955), (42.316902, -71.091946)] != [(42.316902, -71.091946)]
# 219: [(42.37430131617823, -71.03808671246952), (42.374335, -71.039685), (42.37430732260765, -71.03807777166365), (42.373312125824704, -71.0410200806291)] != [(42.374335, -71.039685), (42.37430732260765, -71.03807777166365), (42.373312125824704, -71.0410200806291)]
# 205: [(42.30791912678712, -71.06502056121826), (42.306348, -71.067149), (42.30785224238503, -71.06512248516083)] != [(42.306348, -71.067149), (42.30785224238503, -71.06512248516083)]
# 153: [(45.505086, -73.566921), (42.37530443828819, -71.08688293667001)] != [(45.505086, -73.566921)]
# 212: [(42.36884408289835, -71.03977829217911)] != [(42.3688385713652, -71.03976666949166), (42.36884408289835, -71.03977829217911)]
# 224: [(42.374035, -71.10402522613185), (42.38267827521855, -71.143478951426)] != [(42.38267827521855, -71.143478951426)]
# 207: [(42.35484, -71.150226)] != [(42.35480179069945, -71.15025043487549), (42.35484, -71.150226)]
# 10

# %%
#compare start and end station
i = 0
for key, value in end_dict.items():
    if key in end_dict:
        if start_dict.get(key) != None:
            if value != start_dict[key]:
                print(str(key) + ": "    + str(value) + " != " + str(start_dict[key]))
                i += 1
i
# Out:
# 77: [(42.386844, -71.09812)] != [(42.386844, -71.09812), (42.396386809455, -71.12226963043213)]
# 212: [(42.3688385713652, -71.03976666949166), (42.36884408289835, -71.03977829217911)] != [(42.36884408289835, -71.03977829217911)]
# 135: [(42.344827, -71.028664)] != [(42.344827, -71.028664), (42.353334, -71.09850591982195)]
# 207: [(42.35480179069945, -71.15025043487549), (42.35484, -71.150226)] != [(42.35484, -71.150226)]
# 153: [(45.505086, -73.566921)] != [(45.505086, -73.566921), (42.37530443828819, -71.08688293667001)]
# 201: [(42.316902, -71.091946)] != [(42.316873, -71.091955), (42.316902, -71.091946)]
# 205: [(42.306348, -71.067149), (42.30785224238503, -71.06512248516083)] != [(42.30791912678712, -71.06502056121826), (42.306348, -71.067149), (42.30785224238503, -71.06512248516083)]
# 219: [(42.374335, -71.039685), (42.37430732260765, -71.03807777166365), (42.373312125824704, -71.0410200806291)] != [(42.37430131617823, -71.03808671246952), (42.374335, -71.039685), (42.37430732260765, -71.03807777166365), (42.373312125824704, -71.0410200806291)]
# 217: [(42.386781, -71.006098)] != [(42.38673178529929, -71.00621223455164), (42.386781, -71.006098)]
# 224: [(42.38267827521855, -71.143478951426)] != [(42.374035, -71.10402522613185), (42.38267827521855, -71.143478951426)]
# 10

# %% [markdown]
# ## Map all stations

# %%
map_stations_all_cords(start_dict)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4564440dee72449f919d45f52eabb2a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4564440dee72449f919d45f52eabb2a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4564440dee72449f919d45f52eabb2a5 = L.map(
#                 &quot;map_4564440dee72449f919d45f52eabb2a5&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e5e6ed1210931141090cfbaba24b98d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4564440dee72449f919d45f52eabb2a5);
#
#
#             var marker_23a47fd64b64b922f7f3d9f65924fa66 = L.marker(
#                 [42.3581, -71.093198],
#                 {}
#             ).addTo(map_4564440dee72449f919d45f52eabb2a5);
#
#
#             var icon_82171cb2b7aef022b24e507adea54b1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_23a47fd64b64b922f7f3d9f65924fa66.setIcon(icon_82171cb2b7aef022b24e507adea54b1a);
#
#
#         var popup_2eb7bbf31dafae5fc7a4f5744afa8f31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20f99bbb822407e149f2fcea98ba62e3 = $(`&lt;div id=&quot;html_20f99bbb822407e149f2fcea98ba62e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;67 (42.3581, -71.093198)&lt;/div&gt;`)[0];
#                 popup_2eb7bbf31dafae5fc7a4f5744afa8f31.setContent(html_20f99bbb822407e149f2fcea98ba62e3);
#
#
#
#         marker_23a47fd64b64b922f7f3d9f65924fa66.bindPopup(popup_2eb7bbf31dafae5fc7a4f5744afa8f31)
#         ;
#
#
#
#
#             var marker_4dce6c1f17fbf1541f83934c023c365e = L.marker(
#                 [42.349673, -71.077303],
#                 {}
#             ).addTo(map_4564440dee72449f919d45f52eabb2a5);
#
#
#             var icon_b936d71454f387d724fb9a3b6c993e0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dce6c1f17fbf1541f83934c023c365e.setIcon(icon_b936d71454f387d724fb9a3b6c993e0c);
#
#
#         var popup_0b23a7ab30c8b345ee98b261f3843daa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37d2cb29ab4750e38bbf9b2281a6a550 = $(`&lt;div id=&quot;html_37d2cb29ab4750e38bbf9b2281a6a550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.349673, -71.077303)&lt;/div&gt;`)[0];
#                 popup_0b23a7ab30c8b345ee98b261f3843daa.setContent(html_37d2cb29ab4750e38bbf9b2281a6a550);
#
#
#
#         marker_4dce6c1f17fbf1541f83934c023c365e.bindPopup(popup_0b23a7ab30c8b345ee98b261f3843daa)
#         ;
#
#
#
#
#             var marker_5a9529172bc4f7a58cac6fd5b8daea56 = L.marker(
#                 [42.34976701008725, -71.07732653617859],
#                 {}
#             ).addTo(map_4564440dee72449f919d45f52eabb2a5);
#
#
#             var icon_d0dbdfbaf89660890d45b1e7da0f7973 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a9529172bc4f7a58cac6fd5b8daea56.setIcon(icon_d0dbdfbaf89660890d45b1e7da0f7973);
#
#
#         var popup_f3b5c4b01004de89a60175b134845342 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f0a94017cdccd3f08b7599ee086b2d5 = $(`&lt;div id=&quot;html_4f0a94017cdccd3f08b7599ee086b2d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.34976701008725, -71.07732653617859)&lt;/div&gt;`)[0];
#                 popup_f3b5c4b01004de89a60175b134845342.setContent(html_4f0a94017cdccd3f08b7599ee086b2d5);
#
#
#
#         marker_5a9529172bc4f7a58cac6fd5b8daea56.bindPopup(popup_f3b5c4b01004de89a60175b134845342)
#         ;
#
#
#
#
#             var marker_8526056c4d0091aa7683d3c29d138de9 = L.marker(
#                 [42.34993463611888, -71.07738554477692],
#                 {}
#             ).addTo(map_4564440dee72449f919d45f52eabb2a5);
#
#
#             var icon_83399a93abc5e31c76f3c34c136c089e = L.AwesomeMarkers.icon(

# %%
map_stations_all_cords(end_dict)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88984e02b1a9514779a38607d7bcdb0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88984e02b1a9514779a38607d7bcdb0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88984e02b1a9514779a38607d7bcdb0d = L.map(
#                 &quot;map_88984e02b1a9514779a38607d7bcdb0d&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20f85561601cd873fa9b81294faa5e37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88984e02b1a9514779a38607d7bcdb0d);
#
#
#             var marker_b1748bad55beb87c955cdbd94bd040a9 = L.marker(
#                 [42.36178043960605, -71.10809952020645],
#                 {}
#             ).addTo(map_88984e02b1a9514779a38607d7bcdb0d);
#
#
#             var icon_a6a265ecbba7b02644c497ee75b4500a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b1748bad55beb87c955cdbd94bd040a9.setIcon(icon_a6a265ecbba7b02644c497ee75b4500a);
#
#
#         var popup_3308fc0e371e8dbae70b40fc0e31fd00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_518ff3d41f3538e2f6b2c2b7bbb4e23b = $(`&lt;div id=&quot;html_518ff3d41f3538e2f6b2c2b7bbb4e23b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;139 (42.36178043960605, -71.10809952020645)&lt;/div&gt;`)[0];
#                 popup_3308fc0e371e8dbae70b40fc0e31fd00.setContent(html_518ff3d41f3538e2f6b2c2b7bbb4e23b);
#
#
#
#         marker_b1748bad55beb87c955cdbd94bd040a9.bindPopup(popup_3308fc0e371e8dbae70b40fc0e31fd00)
#         ;
#
#
#
#
#             var marker_debd62550932086d03c728327d905f0b = L.marker(
#                 [42.350406, -71.108279],
#                 {}
#             ).addTo(map_88984e02b1a9514779a38607d7bcdb0d);
#
#
#             var icon_a7dff0b45e3669f1b450a76d849f86f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_debd62550932086d03c728327d905f0b.setIcon(icon_a7dff0b45e3669f1b450a76d849f86f5);
#
#
#         var popup_7733eef980073733948312448fc12c39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8129e12c26f244b39104c0de689cca4b = $(`&lt;div id=&quot;html_8129e12c26f244b39104c0de689cca4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10 (42.350406, -71.108279)&lt;/div&gt;`)[0];
#                 popup_7733eef980073733948312448fc12c39.setContent(html_8129e12c26f244b39104c0de689cca4b);
#
#
#
#         marker_debd62550932086d03c728327d905f0b.bindPopup(popup_7733eef980073733948312448fc12c39)
#         ;
#
#
#
#
#             var marker_241ed48737cb2f347d3180f2a4aee252 = L.marker(
#                 [42.351246, -71.115639],
#                 {}
#             ).addTo(map_88984e02b1a9514779a38607d7bcdb0d);
#
#
#             var icon_185cc9a1047b0df830cf5815640da56b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_241ed48737cb2f347d3180f2a4aee252.setIcon(icon_185cc9a1047b0df830cf5815640da56b);
#
#
#         var popup_f92207b37ad1723ec85f0216bc938cdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_698ad9d78031a411d79a16366ab96d18 = $(`&lt;div id=&quot;html_698ad9d78031a411d79a16366ab96d18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9 (42.351246, -71.115639)&lt;/div&gt;`)[0];
#                 popup_f92207b37ad1723ec85f0216bc938cdc.setContent(html_698ad9d78031a411d79a16366ab96d18);
#
#
#
#         marker_241ed48737cb2f347d3180f2a4aee252.bindPopup(popup_f92207b37ad1723ec85f0216bc938cdc)
#         ;
#
#
#
#
#             var marker_27f9d8ea3d96d276cf446b3324d4c6d0 = L.marker(
#                 [42.35062177153799, -71.11288218766276],
#                 {}
#             ).addTo(map_88984e02b1a9514779a38607d7bcdb0d);
#
#
#             var icon_e287f29ae9497d6bb0448a9123e48dfb = L.AwesomeMarkers.icon(

# %%
map_stations_all_cords(all_station)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32c0d7ecbd8905b3881497fd5988d60c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32c0d7ecbd8905b3881497fd5988d60c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32c0d7ecbd8905b3881497fd5988d60c = L.map(
#                 &quot;map_32c0d7ecbd8905b3881497fd5988d60c&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3837a338a19efad8fc41156e69b1a7dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32c0d7ecbd8905b3881497fd5988d60c);
#
#
#             var marker_1dec53c3ce4bb51024de97f8dcd79695 = L.marker(
#                 [42.3581, -71.093198],
#                 {}
#             ).addTo(map_32c0d7ecbd8905b3881497fd5988d60c);
#
#
#             var icon_3e0d15bb4c2a2a5a9f205731f9153d51 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1dec53c3ce4bb51024de97f8dcd79695.setIcon(icon_3e0d15bb4c2a2a5a9f205731f9153d51);
#
#
#         var popup_70f24d99372ff0af529087cdee0878c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0ce05ec590a65e59a606112ceca4bab = $(`&lt;div id=&quot;html_c0ce05ec590a65e59a606112ceca4bab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;67 (42.3581, -71.093198)&lt;/div&gt;`)[0];
#                 popup_70f24d99372ff0af529087cdee0878c3.setContent(html_c0ce05ec590a65e59a606112ceca4bab);
#
#
#
#         marker_1dec53c3ce4bb51024de97f8dcd79695.bindPopup(popup_70f24d99372ff0af529087cdee0878c3)
#         ;
#
#
#
#
#             var marker_4e29f695bcff36148324d25847875ba6 = L.marker(
#                 [42.36178043960605, -71.10809952020645],
#                 {}
#             ).addTo(map_32c0d7ecbd8905b3881497fd5988d60c);
#
#
#             var icon_5c95e33ab9d1a7541cf31954d1cd3052 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4e29f695bcff36148324d25847875ba6.setIcon(icon_5c95e33ab9d1a7541cf31954d1cd3052);
#
#
#         var popup_f14876e34f86334c536f00536ea47010 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8dc25e3e00ae11f950def7b0a66b81a5 = $(`&lt;div id=&quot;html_8dc25e3e00ae11f950def7b0a66b81a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;139 (42.36178043960605, -71.10809952020645)&lt;/div&gt;`)[0];
#                 popup_f14876e34f86334c536f00536ea47010.setContent(html_8dc25e3e00ae11f950def7b0a66b81a5);
#
#
#
#         marker_4e29f695bcff36148324d25847875ba6.bindPopup(popup_f14876e34f86334c536f00536ea47010)
#         ;
#
#
#
#
#             var marker_226e972c944a677750796e042ac9177c = L.marker(
#                 [42.349673, -71.077303],
#                 {}
#             ).addTo(map_32c0d7ecbd8905b3881497fd5988d60c);
#
#
#             var icon_5f3c5ea4274d831d2447bbf19e6a8118 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_226e972c944a677750796e042ac9177c.setIcon(icon_5f3c5ea4274d831d2447bbf19e6a8118);
#
#
#         var popup_b61e7b5e20d833531d7e4f7054a5a97c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f637d1f0ea00fc32b0ac1e73c9b16f5b = $(`&lt;div id=&quot;html_f637d1f0ea00fc32b0ac1e73c9b16f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.349673, -71.077303)&lt;/div&gt;`)[0];
#                 popup_b61e7b5e20d833531d7e4f7054a5a97c.setContent(html_f637d1f0ea00fc32b0ac1e73c9b16f5b);
#
#
#
#         marker_226e972c944a677750796e042ac9177c.bindPopup(popup_b61e7b5e20d833531d7e4f7054a5a97c)
#         ;
#
#
#
#
#             var marker_1c36a0b8b8b09a7249ab896f0bc5ad0c = L.marker(
#                 [42.34976701008725, -71.07732653617859],
#                 {}
#             ).addTo(map_32c0d7ecbd8905b3881497fd5988d60c);
#
#
#             var icon_53808f52d184666eaec91e8686f73231 = L.AwesomeMarkers.icon(

# %% [markdown]
# Outlier on the map:
#
# 379: (-90.0,0.0), 158 (0.0, 0.0), 153 (45.505086, -73.566921), 308 (42.16722555541654, -70.90555783370291)

# %% [markdown]
# All stations with multiple positions

# %%
map_stations_with_multiple_coordinates(all_station)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_746e4c044484f1c3be276f0dbb546b0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_746e4c044484f1c3be276f0dbb546b0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_746e4c044484f1c3be276f0dbb546b0b = L.map(
#                 &quot;map_746e4c044484f1c3be276f0dbb546b0b&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57c46525943535003dea7b01c72e3e88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_746e4c044484f1c3be276f0dbb546b0b);
#
#
#             var marker_03fcf0161354c982313203bf16806206 = L.marker(
#                 [42.349673, -71.077303],
#                 {}
#             ).addTo(map_746e4c044484f1c3be276f0dbb546b0b);
#
#
#             var icon_8645d6d2d700aa2439d728f9521610ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03fcf0161354c982313203bf16806206.setIcon(icon_8645d6d2d700aa2439d728f9521610ea);
#
#
#         var popup_14c7bc523b5c207638195a42a9c5025e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67a8507a8734bb767be0a4ceee2f4593 = $(`&lt;div id=&quot;html_67a8507a8734bb767be0a4ceee2f4593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36&lt;/div&gt;`)[0];
#                 popup_14c7bc523b5c207638195a42a9c5025e.setContent(html_67a8507a8734bb767be0a4ceee2f4593);
#
#
#
#         marker_03fcf0161354c982313203bf16806206.bindPopup(popup_14c7bc523b5c207638195a42a9c5025e)
#         ;
#
#
#
#
#             var marker_422373c009cf13f3ac6931e0609cb081 = L.marker(
#                 [42.34976701008725, -71.07732653617859],
#                 {}
#             ).addTo(map_746e4c044484f1c3be276f0dbb546b0b);
#
#
#             var icon_5f58cc2694841ced3ab2a522d44cb9e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_422373c009cf13f3ac6931e0609cb081.setIcon(icon_5f58cc2694841ced3ab2a522d44cb9e7);
#
#
#         var popup_f9b3e95b199d307086cf571e569e4b27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29c44fcfcaed5754c90a0bd6103ef6e9 = $(`&lt;div id=&quot;html_29c44fcfcaed5754c90a0bd6103ef6e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36&lt;/div&gt;`)[0];
#                 popup_f9b3e95b199d307086cf571e569e4b27.setContent(html_29c44fcfcaed5754c90a0bd6103ef6e9);
#
#
#
#         marker_422373c009cf13f3ac6931e0609cb081.bindPopup(popup_f9b3e95b199d307086cf571e569e4b27)
#         ;
#
#
#
#
#             var marker_520e2d727cb8c37419c82d6519c601de = L.marker(
#                 [42.34993463611888, -71.07738554477692],
#                 {}
#             ).addTo(map_746e4c044484f1c3be276f0dbb546b0b);
#
#
#             var icon_a8f69c8d804e202ffbedbca768076efa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_520e2d727cb8c37419c82d6519c601de.setIcon(icon_a8f69c8d804e202ffbedbca768076efa);
#
#
#         var popup_8577014468d37fe954d7cec852842f8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8838876a7c728bc271c494d5915bd46 = $(`&lt;div id=&quot;html_c8838876a7c728bc271c494d5915bd46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36&lt;/div&gt;`)[0];
#                 popup_8577014468d37fe954d7cec852842f8d.setContent(html_c8838876a7c728bc271c494d5915bd46);
#
#
#
#         marker_520e2d727cb8c37419c82d6519c601de.bindPopup(popup_8577014468d37fe954d7cec852842f8d)
#         ;
#
#
#
#
#             var marker_6a7c916afc12f0a0135e6e5b6174883c = L.marker(
#                 [42.351246, -71.115639],
#                 {}
#             ).addTo(map_746e4c044484f1c3be276f0dbb546b0b);
#
#
#             var icon_49e1fba66cdffe4328634108ecef6510 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quo

# %% [markdown]
# New outlier found:
#
# 229 (0.0, 0.0)

# %% [markdown]
# Search for all stations with coordinates in the outlier range

# %%
outlier_cords = [(0.0, 0.0), (-90.0,0.0), (45.505086, -73.566921), (42.16722555541654, -70.90555783370291)]

# %%
for key, value in start_dict.items():
    for point in value:
        if point in outlier_cords:
            print(str(key) + ": " + str(point))
# Out:
# 153: (45.505086, -73.566921)
# 229: (0.0, 0.0)
# 230: (0.0, 0.0)
# 164: (0.0, 0.0)
# 158: (0.0, 0.0)
# 308: (42.16722555541654, -70.90555783370291)

# %% [markdown]
# Outliers found:
#
#
# 153: (45.505086, -73.566921),
# 229: (0.0, 0.0),
# 230: (0.0, 0.0),
# 164: (0.0, 0.0),
# 158: (0.0, 0.0),
# 308: (42.16722555541654, -70.90555783370291)

# %%
far_away_map(all_station)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39a85fd3a3e94f0ff4a3857c9dcb1d9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39a85fd3a3e94f0ff4a3857c9dcb1d9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39a85fd3a3e94f0ff4a3857c9dcb1d9c = L.map(
#                 &quot;map_39a85fd3a3e94f0ff4a3857c9dcb1d9c&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d186b16d5275316f71be77b2804c8be6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39a85fd3a3e94f0ff4a3857c9dcb1d9c);
#
#
#             var marker_105340896f8209405212dbb7df427ffb = L.marker(
#                 [42.386844, -71.09812],
#                 {}
#             ).addTo(map_39a85fd3a3e94f0ff4a3857c9dcb1d9c);
#
#
#             var icon_f73f783ed191eb936718bb4fd5772d16 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_105340896f8209405212dbb7df427ffb.setIcon(icon_f73f783ed191eb936718bb4fd5772d16);
#
#
#         var popup_644be08be9c3dba16910bc40baf72403 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a015a445210a6055ddbcee358ac397a = $(`&lt;div id=&quot;html_8a015a445210a6055ddbcee358ac397a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;77 (42.386844, -71.09812)&lt;/div&gt;`)[0];
#                 popup_644be08be9c3dba16910bc40baf72403.setContent(html_8a015a445210a6055ddbcee358ac397a);
#
#
#
#         marker_105340896f8209405212dbb7df427ffb.bindPopup(popup_644be08be9c3dba16910bc40baf72403)
#         ;
#
#
#
#
#             var marker_13061952d4522e073e422f13a91d781d = L.marker(
#                 [42.396386809455, -71.12226963043213],
#                 {}
#             ).addTo(map_39a85fd3a3e94f0ff4a3857c9dcb1d9c);
#
#
#             var icon_f0c08889d27e155404b962e01710d29d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13061952d4522e073e422f13a91d781d.setIcon(icon_f0c08889d27e155404b962e01710d29d);
#
#
#         var popup_a103fa65089cb3eeecdb58c513830a1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e0f533eb648ec868bf64087fa1ab2ba = $(`&lt;div id=&quot;html_5e0f533eb648ec868bf64087fa1ab2ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;77 (42.396386809455, -71.12226963043213)&lt;/div&gt;`)[0];
#                 popup_a103fa65089cb3eeecdb58c513830a1e.setContent(html_5e0f533eb648ec868bf64087fa1ab2ba);
#
#
#
#         marker_13061952d4522e073e422f13a91d781d.bindPopup(popup_a103fa65089cb3eeecdb58c513830a1e)
#         ;
#
#
#
#
#             var marker_6b6cbb02beeb86926c3b7d15b75cdbeb = L.marker(
#                 [42.344827, -71.028664],
#                 {}
#             ).addTo(map_39a85fd3a3e94f0ff4a3857c9dcb1d9c);
#
#
#             var icon_7978fdc71265e21636e6b9d33b3c6406 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b6cbb02beeb86926c3b7d15b75cdbeb.setIcon(icon_7978fdc71265e21636e6b9d33b3c6406);
#
#
#         var popup_28cbd2c11e3266ab5b7de8045dafbd7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_264be5d415ac30ed361503b6f2d257a4 = $(`&lt;div id=&quot;html_264be5d415ac30ed361503b6f2d257a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;135 (42.344827, -71.028664)&lt;/div&gt;`)[0];
#                 popup_28cbd2c11e3266ab5b7de8045dafbd7f.setContent(html_264be5d415ac30ed361503b6f2d257a4);
#
#
#
#         marker_6b6cbb02beeb86926c3b7d15b75cdbeb.bindPopup(popup_28cbd2c11e3266ab5b7de8045dafbd7f)
#         ;
#
#
#
#
#             var marker_15b20316446e01af735c912baac003ae = L.marker(
#                 [42.353334, -71.09850591982195],
#                 {}
#             ).addTo(map_39a85fd3a3e94f0ff4a3857c9dcb1d9c);
#
#
#             var icon_8a24376ffebb7a67fa0d248b7d5de5b5 = L.AwesomeMarkers.icon(

# %% [markdown]
# New outlier candidates: 135 (42.353334, -71.09850591982195), 224, 77

# %% [markdown]
# ## Further data cleaning

# %%
outlier_cords
# Out:
# [(0.0, 0.0),
#  (-90.0, 0.0),
#  (45.505086, -73.566921),
#  (42.16722555541654, -70.90555783370291)]

# %% [markdown]
# Remove clear outliers

# %%
bluebikes_clean = bluebikes.copy()
for point in outlier_cords:
    bluebikes_clean = bluebikes_clean[~((bluebikes_clean.start_station_lat == point[0]) & (bluebikes_clean.start_station_lon == point[1]))]
    bluebikes_clean = bluebikes_clean[~((bluebikes_clean.end_station_lat == point[0]) & (bluebikes_clean.end_station_lon == point[1]))]

# %%
start_dict, end_dict, all_station = get_station_dict(bluebikes_clean)

# %%
all_station.keys().__len__()
# Out:
# 313

# %%
all_station[135]
# Out:
# [(42.344827, -71.028664)]

# %%
map_stations_all_cords(all_station)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb98ad0f9a468e91df606687628c4290 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb98ad0f9a468e91df606687628c4290&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb98ad0f9a468e91df606687628c4290 = L.map(
#                 &quot;map_eb98ad0f9a468e91df606687628c4290&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_933595d61cb92205e46bca93eef686d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb98ad0f9a468e91df606687628c4290);
#
#
#             var marker_26ac0780b8aab5ddd192c373b53e4846 = L.marker(
#                 [42.3581, -71.093198],
#                 {}
#             ).addTo(map_eb98ad0f9a468e91df606687628c4290);
#
#
#             var icon_94031fabcddaec366280d509920c391c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26ac0780b8aab5ddd192c373b53e4846.setIcon(icon_94031fabcddaec366280d509920c391c);
#
#
#         var popup_648a033d96e87f3ca794084a7b45a032 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cacb0e1f406d4363b983a810b00aa5e = $(`&lt;div id=&quot;html_5cacb0e1f406d4363b983a810b00aa5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;67 (42.3581, -71.093198)&lt;/div&gt;`)[0];
#                 popup_648a033d96e87f3ca794084a7b45a032.setContent(html_5cacb0e1f406d4363b983a810b00aa5e);
#
#
#
#         marker_26ac0780b8aab5ddd192c373b53e4846.bindPopup(popup_648a033d96e87f3ca794084a7b45a032)
#         ;
#
#
#
#
#             var marker_cbed7680d1c98c935d7a336de1d31a1b = L.marker(
#                 [42.36178043960605, -71.10809952020645],
#                 {}
#             ).addTo(map_eb98ad0f9a468e91df606687628c4290);
#
#
#             var icon_6fd270b544ef252aeae0c1936ed748d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbed7680d1c98c935d7a336de1d31a1b.setIcon(icon_6fd270b544ef252aeae0c1936ed748d0);
#
#
#         var popup_a733c4bb9e9426c7a07c9fbef4834ccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfea3328393993b18ce441c07e06da9b = $(`&lt;div id=&quot;html_cfea3328393993b18ce441c07e06da9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;139 (42.36178043960605, -71.10809952020645)&lt;/div&gt;`)[0];
#                 popup_a733c4bb9e9426c7a07c9fbef4834ccf.setContent(html_cfea3328393993b18ce441c07e06da9b);
#
#
#
#         marker_cbed7680d1c98c935d7a336de1d31a1b.bindPopup(popup_a733c4bb9e9426c7a07c9fbef4834ccf)
#         ;
#
#
#
#
#             var marker_64107be058c74a792d8e0538a1ee2ac7 = L.marker(
#                 [42.349673, -71.077303],
#                 {}
#             ).addTo(map_eb98ad0f9a468e91df606687628c4290);
#
#
#             var icon_cdabc45a4cb66006530eb64605d9a6f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_64107be058c74a792d8e0538a1ee2ac7.setIcon(icon_cdabc45a4cb66006530eb64605d9a6f5);
#
#
#         var popup_463ce3ae23bb01ad0c48fbd7a09d31a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67af38e41da23ddbcf92951b20266171 = $(`&lt;div id=&quot;html_67af38e41da23ddbcf92951b20266171&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.349673, -71.077303)&lt;/div&gt;`)[0];
#                 popup_463ce3ae23bb01ad0c48fbd7a09d31a8.setContent(html_67af38e41da23ddbcf92951b20266171);
#
#
#
#         marker_64107be058c74a792d8e0538a1ee2ac7.bindPopup(popup_463ce3ae23bb01ad0c48fbd7a09d31a8)
#         ;
#
#
#
#
#             var marker_98c0a0788fb06eb1175e5e28f8d543e7 = L.marker(
#                 [42.34976701008725, -71.07732653617859],
#                 {}
#             ).addTo(map_eb98ad0f9a468e91df606687628c4290);
#
#
#             var icon_a1901be5cb43cd8143c0d2ccf7425205 = L.AwesomeMarkers.icon(

# %%
map_stations_with_multiple_coordinates(all_station)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecf3ac2f0bed822a5755642527c28c41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecf3ac2f0bed822a5755642527c28c41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecf3ac2f0bed822a5755642527c28c41 = L.map(
#                 &quot;map_ecf3ac2f0bed822a5755642527c28c41&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdca84a20f9c6e23df80d7f9b0106dc6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ecf3ac2f0bed822a5755642527c28c41);
#
#
#             var marker_38b387702203c023998817bedfd65719 = L.marker(
#                 [42.349673, -71.077303],
#                 {}
#             ).addTo(map_ecf3ac2f0bed822a5755642527c28c41);
#
#
#             var icon_34a6be1e51cb17cc517b1f32cf14a70a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_38b387702203c023998817bedfd65719.setIcon(icon_34a6be1e51cb17cc517b1f32cf14a70a);
#
#
#         var popup_88b170f319cb9de631e30c5556233f4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89c9c074ee52b34ccf5ef5fd0c317060 = $(`&lt;div id=&quot;html_89c9c074ee52b34ccf5ef5fd0c317060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.349673, -71.077303)&lt;/div&gt;`)[0];
#                 popup_88b170f319cb9de631e30c5556233f4a.setContent(html_89c9c074ee52b34ccf5ef5fd0c317060);
#
#
#
#         marker_38b387702203c023998817bedfd65719.bindPopup(popup_88b170f319cb9de631e30c5556233f4a)
#         ;
#
#
#
#
#             var marker_911655864ae543eb842c1e522b7cd2f8 = L.marker(
#                 [42.34976701008725, -71.07732653617859],
#                 {}
#             ).addTo(map_ecf3ac2f0bed822a5755642527c28c41);
#
#
#             var icon_66492a5b93ceaf1aa82bce1ee50de6cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_911655864ae543eb842c1e522b7cd2f8.setIcon(icon_66492a5b93ceaf1aa82bce1ee50de6cb);
#
#
#         var popup_3f3044ea3114c90fbb25f48aa4bd686f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69aaf41d172ff3c1f899acd332aef5d1 = $(`&lt;div id=&quot;html_69aaf41d172ff3c1f899acd332aef5d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.34976701008725, -71.07732653617859)&lt;/div&gt;`)[0];
#                 popup_3f3044ea3114c90fbb25f48aa4bd686f.setContent(html_69aaf41d172ff3c1f899acd332aef5d1);
#
#
#
#         marker_911655864ae543eb842c1e522b7cd2f8.bindPopup(popup_3f3044ea3114c90fbb25f48aa4bd686f)
#         ;
#
#
#
#
#             var marker_71b5803ee1b830eaf5ef183df0a67c61 = L.marker(
#                 [42.34993463611888, -71.07738554477692],
#                 {}
#             ).addTo(map_ecf3ac2f0bed822a5755642527c28c41);
#
#
#             var icon_300772a68c5f685886377cb1551592e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_71b5803ee1b830eaf5ef183df0a67c61.setIcon(icon_300772a68c5f685886377cb1551592e3);
#
#
#         var popup_f8be852cccda717fcffefd940b0e0fed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e13c135c4afed76b0749c49c34d608b = $(`&lt;div id=&quot;html_6e13c135c4afed76b0749c49c34d608b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36 (42.34993463611888, -71.07738554477692)&lt;/div&gt;`)[0];
#                 popup_f8be852cccda717fcffefd940b0e0fed.setContent(html_6e13c135c4afed76b0749c49c34d608b);
#
#
#
#         marker_71b5803ee1b830eaf5ef183df0a67c61.bindPopup(popup_f8be852cccda717fcffefd940b0e0fed)
#         ;
#
#
#
#
#             var marker_1b57d311f022514806489f7408057254 = L.marker(
#                 [42.351246, -71.115639],
#                 {}
#             ).addTo(map_ecf3ac2f0bed822a5755642527c28c41);
#
#
#             var icon_60ffa8650d59cc2a754bcaf639c6caa4 = L.Awesome

# %%
far_away_map(all_station, 0.25)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3429b41198b4094b68310f17fe180cb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3429b41198b4094b68310f17fe180cb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3429b41198b4094b68310f17fe180cb4 = L.map(
#                 &quot;map_3429b41198b4094b68310f17fe180cb4&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2425887ad02c9f6ff8219f4f41d0e7c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3429b41198b4094b68310f17fe180cb4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# No more big outliers

# %%
far_away_map(all_station, 0.15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d = L.map(
#                 &quot;map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7b130a8425d1f649453d47993a9abae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d);
#
#
#             var marker_d7333bc70be97b21d40bc4fef990f4d7 = L.marker(
#                 [42.351246, -71.115639],
#                 {}
#             ).addTo(map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d);
#
#
#             var icon_1eabeebecf7b22170b0310de4673b35a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7333bc70be97b21d40bc4fef990f4d7.setIcon(icon_1eabeebecf7b22170b0310de4673b35a);
#
#
#         var popup_a8c20a597df8417253b2f79e4aac1430 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b57801b24da45918c7e3b0a96e1bb273 = $(`&lt;div id=&quot;html_b57801b24da45918c7e3b0a96e1bb273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9 (42.351246, -71.115639)&lt;/div&gt;`)[0];
#                 popup_a8c20a597df8417253b2f79e4aac1430.setContent(html_b57801b24da45918c7e3b0a96e1bb273);
#
#
#
#         marker_d7333bc70be97b21d40bc4fef990f4d7.bindPopup(popup_a8c20a597df8417253b2f79e4aac1430)
#         ;
#
#
#
#
#             var marker_5b4ca8ecfad23727d3d7d329aba7589e = L.marker(
#                 [42.35062177153799, -71.11288218766276],
#                 {}
#             ).addTo(map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d);
#
#
#             var icon_85311eea624e1459a06616e84adfba22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5b4ca8ecfad23727d3d7d329aba7589e.setIcon(icon_85311eea624e1459a06616e84adfba22);
#
#
#         var popup_a0246ee1c9fdf335fd4518f7308c84fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7482f14d491741ccca230f2df6757696 = $(`&lt;div id=&quot;html_7482f14d491741ccca230f2df6757696&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9 (42.35062177153799, -71.11288218766276)&lt;/div&gt;`)[0];
#                 popup_a0246ee1c9fdf335fd4518f7308c84fa.setContent(html_7482f14d491741ccca230f2df6757696);
#
#
#
#         marker_5b4ca8ecfad23727d3d7d329aba7589e.bindPopup(popup_a0246ee1c9fdf335fd4518f7308c84fa)
#         ;
#
#
#
#
#             var marker_f39c206780fb99f3e43da30ce5d733e5 = L.marker(
#                 [42.35169201885973, -71.11903488636017],
#                 {}
#             ).addTo(map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d);
#
#
#             var icon_2a23428d964d13e53ed7950c334b4ece = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f39c206780fb99f3e43da30ce5d733e5.setIcon(icon_2a23428d964d13e53ed7950c334b4ece);
#
#
#         var popup_626800d1bf63329fe527e747c2468c75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_091dfd8e3b477c491c8deb280c38c406 = $(`&lt;div id=&quot;html_091dfd8e3b477c491c8deb280c38c406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9 (42.35169201885973, -71.11903488636017)&lt;/div&gt;`)[0];
#                 popup_626800d1bf63329fe527e747c2468c75.setContent(html_091dfd8e3b477c491c8deb280c38c406);
#
#
#
#         marker_f39c206780fb99f3e43da30ce5d733e5.bindPopup(popup_626800d1bf63329fe527e747c2468c75)
#         ;
#
#
#
#
#             var marker_d5b374535fa5cec77191d96df3bfcbf1 = L.marker(
#                 [42.37430131617823, -71.03808671246952],
#                 {}
#             ).addTo(map_2f1fb8b3b9da3e6e2f33b4a99b4e6a7d);
#
#
#             var icon_3b5c15db303fe0e520a41d99d6e39f4

# %% [markdown]
# Still some small differences left.
#
# To fix this we will use the average of the coordinates of the stations with the same id.

# %%
all_station_average = {}
for key, value in all_station.items():
    lat = 0
    lon = 0
    for point in value:
        lat += point[0]
        lon += point[1]
    lat /= len(value)
    lon /= len(value)
    all_station_average[key] = ((lat, lon))

# %%
stations = pd.DataFrame.from_dict(all_station_average, orient='index', columns=['lat', 'lon'])

# %%
stations = pd.DataFrame({'station_id': list(all_station_average.keys()), 'lat': [x[0] for x in list(all_station_average.values())], 'lon': [x[1] for x in list(all_station_average.values())]})

# %%
stations.head(5)
# Out:
#    station_id        lat        lon
# 0          67  42.358100 -71.093198
# 1         139  42.361780 -71.108100
# 2          36  42.349792 -71.077338
# 3          10  42.350406 -71.108279
# 4           9  42.351187 -71.115852

# %%
#map stations with folium
bluebikes_map_points = folium.Map(location=(42.361145, -71.057083), tiles="OpenStreetMap", zoom_start=12)

for index, row in stations.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['station_id']).add_to(bluebikes_map_points)
bluebikes_map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00b320aa0163967df168b124e45b2c58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00b320aa0163967df168b124e45b2c58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00b320aa0163967df168b124e45b2c58 = L.map(
#                 &quot;map_00b320aa0163967df168b124e45b2c58&quot;,
#                 {
#                     center: [42.361145, -71.057083],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d0d35114c4fa6d0261dbd270369a0ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00b320aa0163967df168b124e45b2c58);
#
#
#             var marker_3ef96c24e510ebf33cc6b389e825a177 = L.marker(
#                 [42.3581, -71.093198],
#                 {}
#             ).addTo(map_00b320aa0163967df168b124e45b2c58);
#
#
#         var popup_4b9a68c54a38a7ce4a1aab79e3b01db5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_994dd0f8a794ff0c6d0427c7782681b7 = $(`&lt;div id=&quot;html_994dd0f8a794ff0c6d0427c7782681b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;67.0&lt;/div&gt;`)[0];
#                 popup_4b9a68c54a38a7ce4a1aab79e3b01db5.setContent(html_994dd0f8a794ff0c6d0427c7782681b7);
#
#
#
#         marker_3ef96c24e510ebf33cc6b389e825a177.bindPopup(popup_4b9a68c54a38a7ce4a1aab79e3b01db5)
#         ;
#
#
#
#
#             var marker_0f720fb54138a67e22486e1ae774e6d6 = L.marker(
#                 [42.36178043960605, -71.10809952020645],
#                 {}
#             ).addTo(map_00b320aa0163967df168b124e45b2c58);
#
#
#         var popup_398aecaec789608f2313aa7e28a97759 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1610000ffe91602fc42146cf259b6a9 = $(`&lt;div id=&quot;html_e1610000ffe91602fc42146cf259b6a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;139.0&lt;/div&gt;`)[0];
#                 popup_398aecaec789608f2313aa7e28a97759.setContent(html_e1610000ffe91602fc42146cf259b6a9);
#
#
#
#         marker_0f720fb54138a67e22486e1ae774e6d6.bindPopup(popup_398aecaec789608f2313aa7e28a97759)
#         ;
#
#
#
#
#             var marker_e2c17d0023f2c78a3690d8732e0b4e86 = L.marker(
#                 [42.349791548735375, -71.0773383603185],
#                 {}
#             ).addTo(map_00b320aa0163967df168b124e45b2c58);
#
#
#         var popup_03feb6d9fe18c6ceb97756ccfc81a1fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7517101f97e5c503df086d3f7ceb7f9 = $(`&lt;div id=&quot;html_a7517101f97e5c503df086d3f7ceb7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_03feb6d9fe18c6ceb97756ccfc81a1fb.setContent(html_a7517101f97e5c503df086d3f7ceb7f9);
#
#
#
#         marker_e2c17d0023f2c78a3690d8732e0b4e86.bindPopup(popup_03feb6d9fe18c6ceb97756ccfc81a1fb)
#         ;
#
#
#
#
#             var marker_35a75d38342f6eb3a6e4b22236281eb6 = L.marker(
#                 [42.350406, -71.108279],
#                 {}
#             ).addTo(map_00b320aa0163967df168b124e45b2c58);
#
#
#         var popup_0658960eb4b7b46d04bd07c467ba9638 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a4c04a2d6f3b353ce660d46ce8aaebb = $(`&lt;div id=&quot;html_8a4c04a2d6f3b353ce660d46ce8aaebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10.0&lt;/div&gt;`)[0];
#                 popup_0658960eb4b7b46d04bd07c467ba9638.setContent(html_8a4c04a2d6f3b353ce660d46ce8aaebb);
#
#
#
#         marker_35a75d38342f6eb3a6e4b22236281eb6.bindPopup(popup_0658960eb4b7b46d04bd07c467ba9638)
#         ;
#
#
#
#
#             var marker_d8b918c2073f20073f1b88a60bf176e8 = L.marker(
#                 [42.35118659679924, -71.11585202467431],
#                 {}
#             ).addTo(map_00b320aa0163967df168b124e45b2c58);
#
#
#         var popup_852e1cd92beb4928bdf99e83089ad7dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b39b67306c25a9edf2062f5782ac141 = $(`&lt;div id=&quot;html_9b39b67306c25a9edf2062f5782ac141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9.0&lt;/div&gt;`)[0];
#                 popup_852e1cd92beb4928bdf99e83089ad7dc.setContent(html_9b39b67306c25a9edf2062f5782ac141);
#
#
#
#         marker_d8b918c2073f20073f1b88a60bf176e8.bindPopup(popup_852e1cd92beb4928bdf99e83089ad7dc)
#         ;
#
#
#
#
#             var marker_08fb98131d807b5f4b8c31a1c2b03532 = L.marker(
#                 [42.3437649122573, -71.0858708871

# %%
stations.to_csv(r"C:\Users\STH_0\Desktop\Data\bluebikes_stations.csv", index=False)
