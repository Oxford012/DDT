# %%
import pandas as pd
data = pd.read_csv('C:/Users/lauri/PycharmProjects/DSML_Data/bluebikes_2017_2018_data/bluebikes_2017_2018')
# Out:
#      city            timestamp  temperature  cloud_cover  \
# 0  Boston  2015-01-01 05:54:00         -6.0           29
# 1  Boston  2015-01-01 06:54:00         -6.0           27
# 2  Boston  2015-01-01 07:54:00         -6.0           27
# 3  Boston  2015-01-01 08:54:00         -4.0           27
# 4  Boston  2015-01-01 09:54:00         -6.0           29
#
#   cloud_cover_description  pressure  windspeed  precipitation  \
# 0           Partly Cloudy   1018.58       17.0            0.0
# 1           Mostly Cloudy   1017.90       17.0            0.0
# 2           Mostly Cloudy   1017.22       19.0            0.0
# 3           Mostly Cloudy   1016.55       20.0            0.0
# 4           Partly Cloudy   1016.21       24.0            0.0
#
#    felt_temperature
# 0             -12.0
# 1             -12.0
# 2             -12.0
# 3             -11.0
# 4             -13.0

# %%
weather = pd.read_csv(r"C:\Users\lauri\PycharmProjects\DSML_Data\Weather_Boston\Boston")
weather.plot()
# Out:
# <Axes: >
